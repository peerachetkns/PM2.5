# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# =====================================
# 📘 Linear SVM Classification with SMOTE
# =====================================

import pandas as pd
import numpy as np
import time
import joblib
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, roc_curve, auc
)
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize
from imblearn.over_sampling import SMOTE
from collections import Counter
import os
os.environ['OMP_NUM_THREADS'] = str(os.cpu_count())
print(f"💻 Using CPU Threads: {os.cpu_count()}")
# Out:
# 💻 Using CPU Threads: 2

# %%
# =======================
# === Block 1: Load Data
# =======================
train_path = "/content/drive/MyDrive/Senior_Project/dataset/PM2.5 dataset/train_split.csv"
test_path  = "/content/drive/MyDrive/Senior_Project/dataset/PM2.5 dataset/test_split.csv"

df_train = pd.read_csv(train_path)
df_test  = pd.read_csv(test_path)

print("✅ Data Loaded Successfully!")
print("Train shape:", df_train.shape)
print("Test shape:", df_test.shape)
# Out:
# ✅ Data Loaded Successfully!
# Train shape: (329623, 13)
# Test shape: (82406, 13)

# %%
# ==============================
# === Block 2: Split Features
# ==============================
target_col = "PM2.5_level"
X_train = df_train.drop(columns=[target_col])
y_train = df_train[target_col]
X_test  = df_test.drop(columns=[target_col])
y_test  = df_test[target_col]

# %%
# =====================================
# === Block 3: Apply SMOTE
# =====================================
from collections import Counter
from imblearn.over_sampling import SMOTE

# ตรวจสอบ class distribution ก่อน oversampling
class_counts = Counter(y_train)
print("\nBefore SMOTE:", class_counts)

# หา class ที่มีจำนวนมากที่สุด (majority)
majority_class_count = max(class_counts.values())

# คำนวณเป้าหมาย: 50% ของจำนวนคลาสที่มากที่สุด
target_size = int(majority_class_count * 0.5)

# สร้าง sampling strategy สำหรับเฉพาะ class 2 และ 3 (ถ้ามีจำนวนน้อยกว่าเป้าหมาย)
sampling_strategy = {
    cls: target_size for cls in [2, 3] if class_counts[cls] < target_size
}

print("Dynamic sampling strategy:", sampling_strategy)

# ใช้ SMOTE ตาม strategy ที่คำนวณได้
smote = SMOTE(random_state=42, sampling_strategy=sampling_strategy)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

print("\nAfter SMOTE:", Counter(y_resampled))
# Out:
# Before SMOTE: Counter({5: 128801, 4: 73062, 1: 64314, 2: 33504, 3: 29942})
# Dynamic sampling strategy: {2: 64400, 3: 64400}
#
# After SMOTE: Counter({5: 128801, 4: 73062, 3: 64400, 2: 64400, 1: 64314})

# %%
# ===========================================
# === Block 4: 10-Fold Cross Validation (Train) + Mean ± SD
# ===========================================
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracy_list, precision_list, recall_list, f1_list, auc_scores = [], [], [], [], []
results = []
print("\n=== 10-Fold Cross Validation Results ===")

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_resampled, y_resampled), 1):
    X_tr, X_val = X_resampled.iloc[train_idx], X_resampled.iloc[val_idx]
    y_tr, y_val = y_resampled.iloc[train_idx], y_resampled.iloc[val_idx]

    model = LinearSVC()
    model.fit(X_tr, y_tr)
    y_pred = model.predict(X_val)

    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_val, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_val, y_pred, average='weighted', zero_division=0)

    # === AUC (One-vs-Rest)
    y_val_bin = label_binarize(y_val, classes=sorted(y_resampled.unique()))
    y_pred_bin = label_binarize(y_pred, classes=sorted(y_resampled.unique()))
    auc_val = roc_auc_score(y_val_bin, y_pred_bin, average='macro', multi_class='ovr')

    results.append([fold, acc, prec, rec, f1, auc_val])
    accuracy_list.append(acc)
    precision_list.append(prec)
    recall_list.append(rec)
    f1_list.append(f1)
    auc_scores.append(auc_val)

    print(f"Fold {fold}: Accuracy={acc:.3f}, Precision={prec:.3f}, "
          f"Recall={rec:.3f}, F1={f1:.3f}, AUC={auc_val:.3f}")

# === ค่าเฉลี่ยรวม ===
acc_mean, acc_sd = np.mean(accuracy_list), np.std(accuracy_list)
prec_mean, prec_sd = np.mean(precision_list), np.std(precision_list)
rec_mean, rec_sd = np.mean(recall_list), np.std(recall_list)
f1_mean, f1_sd = np.mean(f1_list), np.std(f1_list)
auc_mean, auc_sd = np.mean(auc_scores), np.std(auc_scores)

print("\n📊 Cross-validation (10 folds) Metrics (Mean ± SD):")
print(f"Accuracy : {acc_mean:.3f} ± {acc_sd:.3f}")
print(f"Precision: {prec_mean:.3f} ± {prec_sd:.3f}")
print(f"Recall   : {rec_mean:.3f} ± {rec_sd:.3f}")
print(f"F1-score : {f1_mean:.3f} ± {f1_sd:.3f}")
print(f"AUC-ROC  : {auc_mean:.3f} ± {auc_sd:.3f}")

# === แสดงเฉลี่ยธรรมดา (เผื่อรายงานต้องการ)
print("\n📈 Cross-validation (10 folds) Avg Metrics:")
print(f"Accuracy: {acc_mean:.3f}, Precision: {prec_mean:.3f}, "
      f"Recall: {rec_mean:.3f}, F1: {f1_mean:.3f}, AUC: {auc_mean:.3f}")
# Out:
# === 10-Fold Cross Validation Results ===
# Fold 1: Accuracy=0.586, Precision=0.539, Recall=0.586, F1=0.537, AUC=0.705
# Fold 2: Accuracy=0.585, Precision=0.540, Recall=0.585, F1=0.536, AUC=0.705
# Fold 3: Accuracy=0.585, Precision=0.538, Recall=0.585, F1=0.536, AUC=0.705
# Fold 4: Accuracy=0.584, Precision=0.536, Recall=0.584, F1=0.536, AUC=0.704
# Fold 5: Accuracy=0.586, Precision=0.539, Recall=0.586, F1=0.538, AUC=0.706
# Fold 6: Accuracy=0.585, Precision=0.539, Recall=0.585, F1=0.536, AUC=0.704
# Fold 7: Accuracy=0.585, Precision=0.538, Recall=0.585, F1=0.537, AUC=0.705
# Fold 8: Accuracy=0.581, Precision=0.535, Recall=0.581, F1=0.532, AUC=0.702
# Fold 9: Accuracy=0.589, Precision=0.544, Recall=0.589, F1=0.541, AUC=0.707
# Fold 10: Accuracy=0.586, Precision=0.540, Recall=0.586, F1=0.538, AUC=0.705
#
# 📊 Cross-validation (10 folds) Metrics (Mean ± SD):
# Accuracy : 0.585 ± 0.002
# Precision: 0.539 ± 0.002
# Recall   : 0.585 ± 0.002
# F1-score : 0.537 ± 0.002
# AUC-ROC  : 0.705 ± 0.001
#
# 📈 Cross-validation (10 folds) Avg Metrics:
# Accuracy: 0.585, Precision: 0.539, Recall: 0.585, F1: 0.537, AUC: 0.705

# %%
# === (Optional) บันทึกค่า Mean ± SD ลงไฟล์ CSV ===
cv_summary = pd.DataFrame([{
    "Accuracy_mean": acc_mean, "Accuracy_sd": acc_sd,
    "Precision_mean": prec_mean, "Precision_sd": prec_sd,
    "Recall_mean": rec_mean, "Recall_sd": rec_sd,
    "F1_mean": f1_mean, "F1_sd": f1_sd,
    "AUC_mean": auc_mean, "AUC_sd": auc_sd
}])

base_path = '/content/drive/MyDrive/Senior_Project/roc/SVM_Roc/Class2-3/MeanSD/'
summary_path = base_path + '2-3SVM_SMOTE_mean_sd.csv'

# ✅ สร้างโฟลเดอร์อัตโนมัติหากยังไม่มี
os.makedirs(base_path, exist_ok=True)

cv_summary.to_csv(summary_path, index=False)
print(f"\n💾 Mean + SD summary saved to {summary_path}")
# Out:
# 💾 Mean + SD summary saved to /content/drive/MyDrive/Senior_Project/roc/SVM_Roc/Class2-3/MeanSD/2-3SVM_SMOTE_mean_sd.csv

# %%
# =====================================
# === Block 5: Final Testing & Report
# =====================================
from sklearn.metrics import classification_report, confusion_matrix

model.fit(X_resampled, y_resampled)
y_pred_test = model.predict(X_test)

test_acc = accuracy_score(y_test, y_pred_test)
test_prec = precision_score(y_test, y_pred_test, average='weighted', zero_division=0)
test_rec = recall_score(y_test, y_pred_test, average='weighted', zero_division=0)
test_f1 = f1_score(y_test, y_pred_test, average='weighted')

y_test_bin = label_binarize(y_test, classes=sorted(y_resampled.unique()))
y_pred_test_bin = label_binarize(y_pred_test, classes=sorted(y_resampled.unique()))
test_auc = roc_auc_score(y_test_bin, y_pred_test_bin, average="macro", multi_class="ovr")

print(f"\n📈 Test Set Metrics:")
print(f"Accuracy: {test_acc:.3f}, Precision: {test_prec:.3f}, Recall: {test_rec:.3f}, F1: {test_f1:.3f}, AUC: {test_auc:.3f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_test, digits=2))

print("Confusion Matrix:")
cm = confusion_matrix(y_test, y_pred_test)
print(cm)
# Out:
# 📈 Test Set Metrics:
# Accuracy: 0.655, Precision: 0.620, Recall: 0.655, F1: 0.613, AUC: 0.711
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.72      0.88      0.79     16078
#            2       0.29      0.30      0.29      8376
#            3       0.31      0.17      0.22      7486
#            4       0.59      0.25      0.36     18265
#            5       0.75      0.98      0.85     32201
#
#     accuracy                           0.66     82406
#    macro avg       0.53      0.52      0.50     82406
# weighted avg       0.62      0.66      0.61     82406
#
# Confusion Matrix:
# [[14134  1336   301   172   135]
#  [ 3991  2479   888   778   240]
#  [ 1187  2370  1295  1760   874]
#  [  389  2217  1553  4627  9479]
#  [   32   153   113   460 31443]]

# %%
# =====================================
# 🧩 Block 6: Confusion Matrix & ROC Curve (SMOTE + LinearSVC)
# =====================================
cm = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(6,5))
plt.imshow(cm, cmap='Blues')
plt.title('Confusion Matrix (Test Set)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.colorbar()
plt.show()

# ROC Curve
classes = model.classes_
n_classes = len(classes)
y_test_bin = label_binarize(y_test, classes=classes)
y_score = model.decision_function(X_test)

fpr, tpr, roc_auc = {}, {}, {}
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8,6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {classes[i]} (AUC = {roc_auc[i]:.3f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (One-vs-Rest) - Test Set (SMOTE, LinearSVC)')
plt.legend(loc='lower right')
plt.show()

# %%
# =====================================
# === Block 7: Save Model, AUC & ROC Points
# =====================================
base_path = '/content/drive/MyDrive/Senior_Project/roc/SVM_Roc/Class2-3/'

joblib.dump(model, base_path + '2-3svm_smote.pkl')
print(f"\n💾 Model saved as {base_path}2-3svm_smote.pkl")

auc_df = pd.DataFrame({
    "Fold": list(range(1, 11)) + ["Test Set"],
    "AUC_ROC": auc_scores + [test_auc]
})
auc_df.to_csv(base_path + '2-3svm_smote_auc.csv', index=False)
print(f"💾 AUC-ROC values saved to {base_path}2-3svm_smote_auc.csv")

# Save ROC points
roc_points = []
for i in range(n_classes):
    for fp, tp in zip(fpr[i], tpr[i]):
        roc_points.append({'Class': i, 'FPR': fp, 'TPR': tp})

roc_df = pd.DataFrame(roc_points)
roc_df.to_csv(base_path + '2-3svm_smote_roc_points.csv', index=False)
print(f"💾 ROC points saved to {base_path}2-3svm_smote_roc_points.csv")

print(f"\n✅ Macro AUC (mean) = {np.mean(list(roc_auc.values())):.4f}")
# Out:
# 💾 Model saved as /content/drive/MyDrive/Senior_Project/roc/SVM_Roc/Class2-3/2-3svm_smote.pkl
# 💾 AUC-ROC values saved to /content/drive/MyDrive/Senior_Project/roc/SVM_Roc/Class2-3/2-3svm_smote_auc.csv
# 💾 ROC points saved to /content/drive/MyDrive/Senior_Project/roc/SVM_Roc/Class2-3/2-3svm_smote_roc_points.csv
#
# ✅ Macro AUC (mean) = 0.8240
